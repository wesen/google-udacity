# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.490891
# Nearest to called: herb, results, retaken, stg, roar, gender, mutt, freshness,
# Nearest to people: restrained, songwriters, retroviruses, putty, christiaan, breeder, universality, genuineness,
# Nearest to states: frankenstein, discography, eras, oersted, linked, raged, catchphrase, dusk,
# Nearest to it: vineyards, housed, summarised, arbuckle, counselor, convinced, mri, usaid,
# Nearest to eight: tufts, appletalk, countered, hobbyist, send, sackville, albicans, lopes,
# Nearest to but: devised, ballistics, rescue, muscles, derivatives, furthered, deprive, xinjiang,
# Nearest to so: harald, zhu, arlo, almost, alluding, suspending, gordon, heroic,
# Nearest to of: calabria, adria, deserves, hokkaido, dependable, regius, hyksos, hatch,
# Nearest to time: interchangeable, guarani, proprietor, mill, aon, jackass, unclear, convincing,
# Nearest to many: darwinian, waldo, espresso, disobey, tsr, reassure, sumerian, michal,
# Nearest to be: limousine, tagalog, experiences, domes, keenan, thickening, laundry, fincher,
# Nearest to american: intricately, onyx, aleppo, vehement, supplier, cartographic, accede, anisotropy,
# Nearest to no: diva, ltc, connecting, asses, zooplankton, returning, slurs, seeds,
# Nearest to may: subsumed, glassy, fcc, pi, constructive, backstage, newspaper, hui,
# Nearest to after: remarks, cutting, concede, incriminating, brugha, asu, bbn, disasters,
# Nearest to zero: twinned, duplication, circulate, cowl, accomplishing, canmore, supplement, nessie,
# Average loss at step 2000: 4.414668
# Average loss at step 4000: 3.914576
# Average loss at step 6000: 3.790634
# Average loss at step 8000: 3.565669
# Average loss at step 10000: 3.527221
# Nearest to called: stg, jello, mutt, bulletins, mandelstam, gender, kd, considered,
# Nearest to people: breeder, songwriters, perro, mutated, genuineness, infrequent, equilibria, retroviruses,
# Nearest to states: frankenstein, discography, catchphrase, linked, ao, wreath, hagbard, oersted,
# Nearest to it: he, this, which, not, there, refuting, that, they,
# Nearest to eight: nine, six, seven, five, three, four, zero, two,
# Nearest to but: and, devised, centrepiece, nocs, which, php, emporia, are,
# Nearest to so: zhu, almost, harald, fainting, know, arlo, qassam, dyslexic,
# Nearest to of: in, deserves, and, for, lagers, schoolchildren, andaman, disrespectful,
# Nearest to time: illusion, elaboration, guarani, mill, haughty, interchangeable, russcol, aon,
# Nearest to many: some, michal, different, reduces, amassed, tsr, such, desktop,
# Nearest to be: have, is, limousine, are, refer, been, mean, by,
# Nearest to american: intricately, internment, rhyolite, compares, incipient, rhythms, vehement, territory,
# Nearest to no: a, diva, ltc, scientists, nothing, infringe, hippodrome, engagement,
# Nearest to may: would, can, could, subsumed, newspaper, bandmates, riddles, conducive,
# Nearest to after: when, jojo, arctocephalus, sunnis, gpmg, loving, princes, on,
# Nearest to zero: five, eight, six, seven, nine, four, three, two,
# Average loss at step 12000: 3.649790
# Average loss at step 14000: 3.607076
# Average loss at step 16000: 3.578517
# Average loss at step 18000: 3.564196
# Average loss at step 20000: 3.581931
# Nearest to called: considered, completely, insubstantial, comprising, jello, mutt, lanzarote, reserving,
# Nearest to people: breeder, hush, songwriters, genuineness, november, eddington, restrained, retroviruses,
# Nearest to states: frankenstein, catchphrase, ao, furthering, experimentation, hague, discography, wreath,
# Nearest to it: he, this, there, which, still, she, they, czar,
# Nearest to eight: nine, six, seven, five, three, four, zero, one,
# Nearest to but: however, did, burnham, streetcars, aspirations, while, was, nutcracker,
# Nearest to so: zhu, know, fainting, arlo, notified, specifically, wysiwyg, dyslexic,
# Nearest to of: insulted, including, pursuits, in, andaman, franciscan, crematorium, chipsets,
# Nearest to time: illusion, russcol, honey, haughty, view, mill, aon, orbs,
# Nearest to many: some, several, these, other, such, different, reduces, various,
# Nearest to be: have, been, refer, mean, was, by, jaco, were,
# Nearest to american: intricately, colombia, internment, utilities, compares, boleslav, incipient, convergent,
# Nearest to no: nothing, got, this, menu, diva, awesome, rosebud, sector,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to after: when, before, during, loving, arctocephalus, sinuous, became, punish,
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Average loss at step 22000: 3.431968
# Average loss at step 24000: 3.497079
# Average loss at step 26000: 3.528091
# Average loss at step 28000: 3.547462
# Average loss at step 30000: 3.536945
# Nearest to called: considered, comprising, bipartite, completely, reserving, lanzarote, plutonium, insubstantial,
# Nearest to people: solenoid, hush, breeder, equilibria, genuineness, copulation, death, numismatic,
# Nearest to states: catchphrase, frankenstein, nations, furthering, ao, hague, burden, lineker,
# Nearest to it: he, this, she, there, they, which, who, chapultepec,
# Nearest to eight: seven, nine, six, five, four, three, two, zero,
# Nearest to but: and, however, which, although, while, though, or, that,
# Nearest to so: fainting, zhu, know, notified, if, arlo, wysiwyg, constantius,
# Nearest to of: in, including, for, from, following, crematorium, foggy, and,
# Nearest to time: abolish, illusion, way, honey, year, russcol, lurking, counsellors,
# Nearest to many: some, several, these, various, such, those, other, all,
# Nearest to be: have, refer, been, were, become, mean, remain, seem,
# Nearest to american: internment, islamic, boleslav, intricately, sixth, polisario, catholic, sandstone,
# Nearest to no: nothing, menu, any, dili, got, hashanah, burned, not,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to after: before, when, during, loving, until, became, sinuous, accountability,
# Nearest to zero: five, seven, four, six, eight, nine, three, two,
# Average loss at step 32000: 3.516833
# Average loss at step 34000: 3.478948
# Average loss at step 36000: 3.465342
# Average loss at step 38000: 3.507947
# Average loss at step 40000: 3.362931
# Nearest to called: considered, comprising, bipartite, known, used, mutt, controlled, insubstantial,
# Nearest to people: solenoid, glass, equilibria, hush, vos, ryaku, unpaid, tack,
# Nearest to states: nations, hague, frankenstein, catchphrase, burden, countries, ruth, pretentious,
# Nearest to it: he, there, this, she, they, that, we, also,
# Nearest to eight: six, seven, nine, five, four, three, zero, one,
# Nearest to but: however, while, although, which, and, though, ncbi, that,
# Nearest to so: zhu, fainting, notified, arlo, if, know, lct, constantius,
# Nearest to of: including, in, crematorium, federico, ebbinghaus, or, franciscan, insulted,
# Nearest to time: illusion, way, russcol, view, abolish, honey, year, fact,
# Nearest to many: some, several, these, various, those, all, such, both,
# Nearest to be: have, been, mean, refer, being, become, is, remain,
# Nearest to american: biota, islamic, british, boleslav, polisario, championship, internment, convergent,
# Nearest to no: any, menu, dili, nothing, burned, got, there, sector,
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to after: before, during, when, until, while, without, sinuous, became,
# Nearest to zero: six, eight, five, seven, four, nine, three, two,
# Average loss at step 42000: 3.467315
# Average loss at step 44000: 3.351192
# Average loss at step 46000: 3.445371
# Average loss at step 48000: 3.425481
# Average loss at step 50000: 3.434509
# Nearest to called: considered, bipartite, named, comprising, now, used, referred, phylogeny,
# Nearest to people: solenoid, obsolete, equilibria, humans, things, children, men, musics,
# Nearest to states: nations, hague, catchphrase, frankenstein, kingdom, burden, smilga, ruth,
# Nearest to it: he, this, she, there, they, which, what, chapultepec,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to but: however, although, and, while, though, which, rearden, totals,
# Nearest to so: thus, then, if, constantius, yao, fainting, know, zhu,
# Nearest to of: in, crematorium, including, primetime, federico, andaman, during, aan,
# Nearest to time: way, year, period, waterway, honey, voice, orbs, russcol,
# Nearest to many: some, several, these, those, all, various, such, other,
# Nearest to be: been, have, remain, become, refer, being, mean, receive,
# Nearest to american: british, english, sincerity, italian, polisario, islamic, french, editor,
# Nearest to no: any, nothing, menu, dili, sector, houdini, got, burned,
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to after: before, when, during, without, through, at, for, while,
# Nearest to zero: five, six, eight, four, seven, nine, two, three,
# Average loss at step 52000: 3.416574
# Average loss at step 54000: 3.427840
# Average loss at step 56000: 3.333890
# Average loss at step 58000: 3.319960
# Average loss at step 60000: 3.392919
# Nearest to called: considered, named, bipartite, referred, used, known, comprising, given,
# Nearest to people: children, men, things, equilibria, musics, solenoid, humans, u,
# Nearest to states: nations, frankenstein, catchphrase, operations, kingdom, burden, hague, state,
# Nearest to it: he, she, there, this, they, which, often, still,
# Nearest to eight: nine, seven, six, five, four, three, two, zero,
# Nearest to but: however, although, and, though, than, which, rearden, while,
# Nearest to so: if, thus, fainting, yao, too, doves, then, know,
# Nearest to of: in, crematorium, including, insulted, isao, at, and, for,
# Nearest to time: way, rambouillet, orbs, waterway, honey, year, illusion, anzus,
# Nearest to many: some, several, these, various, those, most, all, few,
# Nearest to be: have, been, refer, are, become, remain, is, receive,
# Nearest to american: british, biota, english, italian, islamic, polisario, russian, french,
# Nearest to no: any, menu, houdini, a, dili, there, burned, chun,
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to after: before, during, when, without, while, despite, until, became,
# Nearest to zero: five, four, six, nine, seven, three, eight, two,
# Average loss at step 62000: 3.403607
# Average loss at step 64000: 3.393860
# Average loss at step 66000: 3.389733
# Average loss at step 68000: 3.374378
# Average loss at step 70000: 3.315098
# Nearest to called: considered, referred, named, bipartite, known, used, see, comprising,
# Nearest to people: words, children, musics, things, men, persons, those, christians,
# Nearest to states: nations, kingdom, frankenstein, hague, operations, state, catchphrase, countries,
# Nearest to it: he, she, this, there, they, still, often, which,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to but: however, although, though, and, while, renga, that, which,
# Nearest to so: doves, too, thus, yao, sometimes, anything, constantius, zhu,
# Nearest to of: including, crematorium, overall, soroban, in, andaman, hestia, like,
# Nearest to time: year, orbs, anzus, way, waterway, period, altruists, convincing,
# Nearest to many: some, several, these, those, various, most, all, few,
# Nearest to be: been, become, refer, have, receive, seem, were, are,
# Nearest to american: british, biota, english, german, italian, championship, polisario, sincerity,
# Nearest to no: any, houdini, knee, econometric, another, mummification, little, chun,
# Nearest to may: can, will, could, should, would, must, might, cannot,
# Nearest to after: before, during, when, despite, without, although, until, began,
# Nearest to zero: five, four, eight, seven, six, three, nine, two,
# Average loss at step 72000: 3.281325
# Average loss at step 74000: 3.342870
# Average loss at step 76000: 3.267982
# Average loss at step 78000: 3.304633
# Average loss at step 80000: 3.353014
# Nearest to called: considered, named, bipartite, referred, known, used, respectability, weighing,
# Nearest to people: men, words, women, children, things, humans, those, scholars,
# Nearest to states: nations, kingdom, operations, hague, catchphrase, frankenstein, motor, argued,
# Nearest to it: he, she, this, there, they, itself, neither, but,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to but: however, although, and, though, while, which, see, he,
# Nearest to so: yao, thus, too, doves, sometimes, before, destroyers, zhu,
# Nearest to of: including, crematorium, insulted, franciscan, in, primetime, cataracts, romany,
# Nearest to time: month, anzus, waterway, period, year, day, thing, abolish,
# Nearest to many: some, several, various, these, those, most, all, especially,
# Nearest to be: been, have, become, refer, receive, remain, seem, is,
# Nearest to american: british, english, canadian, s, german, italian, australian, and,
# Nearest to no: any, little, dili, houdini, another, replacements, nothing, it,
# Nearest to may: can, could, will, should, must, would, might, cannot,
# Nearest to after: before, during, when, without, despite, through, until, katanga,
# Nearest to zero: six, seven, eight, nine, five, four, two, three,
# Average loss at step 82000: 3.241872
# Average loss at step 84000: 3.386225
# Average loss at step 86000: 3.356789
# Average loss at step 88000: 3.326703
# Average loss at step 90000: 3.191885
# Nearest to called: named, considered, bipartite, referred, known, respectability, used, schott,
# Nearest to people: men, children, women, words, christians, things, humans, persons,
# Nearest to states: nations, kingdom, state, operations, countries, catchphrase, provinces, complained,
# Nearest to it: he, she, there, this, they, itself, still, no,
# Nearest to eight: six, seven, five, nine, four, three, two, one,
# Nearest to but: however, although, though, and, inertial, which, preferring, while,
# Nearest to so: thus, yao, too, if, zhu, constantius, destroyers, regimental,
# Nearest to of: including, in, surrounding, for, following, pragmatics, soroban, mouvement,
# Nearest to time: way, month, year, waterway, anzus, slovenes, abolish, convincing,
# Nearest to many: some, several, various, those, all, these, both, most,
# Nearest to be: been, become, have, receive, refer, were, seem, mean,
# Nearest to american: british, european, italian, african, australian, including, international, biota,
# Nearest to no: any, little, it, there, dili, chun, nothing, yoshi,
# Nearest to may: can, should, could, might, would, must, will, cannot,
# Nearest to after: before, during, when, without, despite, transvestite, through, philistine,
# Nearest to zero: five, six, four, eight, nine, seven, two, three,
# Average loss at step 92000: 3.302313
# Average loss at step 94000: 3.348843
# Average loss at step 96000: 3.368505
# Average loss at step 98000: 3.368417
# Average loss at step 100000: 3.361341
# Nearest to called: referred, considered, named, known, bipartite, respectability, used, see,
# Nearest to people: men, women, words, children, persons, things, man, scholars,
# Nearest to states: nations, kingdom, state, operations, complained, argued, countries, provinces,
# Nearest to it: he, she, there, this, they, we, you, still,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to but: however, although, though, and, which, generally, that, analyzer,
# Nearest to so: thus, too, yao, sometimes, constantius, destroyers, regimental, how,
# Nearest to of: in, for, including, crematorium, on, franciscan, includes, introspection,
# Nearest to time: month, year, way, clermont, day, period, waterway, jock,
# Nearest to many: several, some, various, those, these, both, all, few,
# Nearest to be: been, become, have, receive, refer, seem, was, is,
# Nearest to american: british, italian, russian, german, english, australian, french, biota,
# Nearest to no: any, little, nothing, yoshi, it, strawberries, dili, knee,
# Nearest to may: can, could, would, might, should, will, must, cannot,
# Nearest to after: before, during, despite, when, without, while, for, hundred,
# Nearest to zero: five, six, seven, eight, nine, four, three, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
generate_batch(128, 2, 1)
# Out:
# (array([ 1375,  1375,    20,    20,    36,    36, 15866, 15866,     7,
#             7,  8209,  8209,     1,     1,   146,   146,    15,    15,
#            14,    14,    44,    44,  1171,  1171,     2,     2,   119,
#           119,   379,   379, 10746, 10746, 10537, 10537, 31582, 31582,
#             0,     0,     0,     0,  6872,  6872,     5,     5,   429,
#           429,    10,    10,     8,     8,     8,     8,    16,    16,
#            61,    61,   931,   931,    17,    17,    81,    81,     5,
#             5,  8793,  8793,    41,    41,  2743,  2743,    30,    30,
#            64,    64, 38322, 38322,     2,     2, 38838, 38838,   119,
#           119,     3,     3,    43,    43, 11974, 11974,  3518,  3518,
#             5,     5,  1634,  1634,     3,     3,  2224,  2224,  1972,
#          1972,     0,     0,     5,     5,    30,    30,    46,    46,
#          1795,  1795,  2409,  2409,   118,   118,    30,    30,   865,
#           865,   923,   923,    36,    36,  7891,  7891,    10,    10,
#            83,    83], dtype=int32), array([[   41],
#         [   20],
#         [   36],
#         [ 1375],
#         [   20],
#         [15866],
#         [   36],
#         [    7],
#         [ 8209],
#         [15866],
#         [    7],
#         [    1],
#         [ 8209],
#         [  146],
#         [   15],
#         [    1],
#         [   14],
#         [  146],
#         [   15],
#         [   44],
#         [ 1171],
#         [   14],
#         [    2],
#         [   44],
#         [ 1171],
#         [  119],
#         [  379],
#         [    2],
#         [10746],
#         [  119],
#         [10537],
#         [  379],
#         [10746],
#         [31582],
#         [10537],
#         [    0],
#         [    0],
#         [31582],
#         [ 6872],
#         [    0],
#         [    5],
#         [    0],
#         [  429],
#         [ 6872],
#         [    5],
#         [   10],
#         [    8],
#         [  429],
#         [    8],
#         [   10],
#         [    8],
#         [   16],
#         [   61],
#         [    8],
#         [   16],
#         [  931],
#         [   61],
#         [   17],
#         [   81],
#         [  931],
#         [   17],
#         [    5],
#         [ 8793],
#         [   81],
#         [    5],
#         [   41],
#         [ 2743],
#         [ 8793],
#         [   30],
#         [   41],
#         [   64],
#         [ 2743],
#         [38322],
#         [   30],
#         [    2],
#         [   64],
#         [38838],
#         [38322],
#         [    2],
#         [  119],
#         [38838],
#         [    3],
#         [  119],
#         [   43],
#         [11974],
#         [    3],
#         [   43],
#         [ 3518],
#         [11974],
#         [    5],
#         [ 3518],
#         [ 1634],
#         [    5],
#         [    3],
#         [ 2224],
#         [ 1634],
#         [ 1972],
#         [    3],
#         [ 2224],
#         [    0],
#         [ 1972],
#         [    5],
#         [   30],
#         [    0],
#         [   46],
#         [    5],
#         [ 1795],
#         [   30],
#         [ 2409],
#         [   46],
#         [ 1795],
#         [  118],
#         [ 2409],
#         [   30],
#         [  865],
#         [  118],
#         [  923],
#         [   30],
#         [   36],
#         [  865],
#         [ 7891],
#         [  923],
#         [   36],
#         [   10],
#         [ 7891],
#         [   83],
#         [   10],
#         [  689]], dtype=int32))

# %%
cbow_data_index = 0

def generate_cbow_batch(batch_size, context_size):
    global cbow_data_index
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    mean_context = np.ndarray(shape=(batch_size, context_size*2), dtype=np.int32)
    
    span = 2 * context_size + 1
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[cbow_data_index])
        cbow_data_index = (cbow_data_index + 1) % len(data)
               
    for i in range(batch_size):
        target = context_size  # target label at the center of the buffer
        targets_to_avoid = [ context_size ]
        batch[i] = buffer[context_size]
        lbuf = list(buffer)
        mean_context[i,:context_size] = lbuf[:context_size]
        mean_context[i, context_size:] = lbuf[context_size+1:]
        
        buffer.append(data[cbow_data_index])
        cbow_data_index = (cbow_data_index + 1) % len(data)

    return mean_context, batch

for context_size in [2, 4]:
    cbow_data_index = 0
    print('\nwith context_size: {}'.format(context_size))
    batch, labels = generate_cbow_batch(batch_size=8, context_size=context_size)
    print('    labels:', [reverse_dictionary[bi] for bi in labels])
    print('    batch:', [[reverse_dictionary[ii] for ii in li] for li in batch])
# Out:
# with context_size: 2
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#
# with context_size: 4
#     labels: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working'], ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class'], ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals'], ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including'], ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_size = 2

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

valid_window = 2000 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
[reverse_dictionary[i] for i in valid_examples]

graph_cbow = tf.Graph()

with graph_cbow.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, context_size*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                             stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed_1 = tf.nn.embedding_lookup(embeddings, train_dataset)
    embed = tf.reduce_mean(embed_1, axis=1)

    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph_cbow) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(batch_size, context_size)
#     print(batch_data.shape)
#     print(batch_labels.shape)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels.reshape((batch_size,1))}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.021631
# Nearest to office: phospholipids, fontaine, frobisher, valium, defun, yoruba, flightless, kd,
# Nearest to appointed: antoninus, mount, screename, deuteronomic, kathleen, ding, cypress, gleichschaltung,
# Nearest to changed: wronged, storehouses, mystique, fauna, baha, pedagogic, checking, electrification,
# Nearest to re: unital, metropolises, fill, commitments, ovens, astrophysicists, arrhythmia, maude,
# Nearest to idea: chargers, abuses, smallest, missile, motet, hippie, tms, mediocre,
# Nearest to football: review, mujahidin, drills, mcclellan, exist, mcleod, aswan, fractures,
# Nearest to continues: quintana, smoother, latent, dummy, gun, gdb, vought, perverse,
# Nearest to until: reluctant, substitutes, teamwork, multilinear, wolfhounds, imply, epsilon, lightsaber,
# Nearest to statistics: fugazi, father, quiver, nger, reveals, hon, wishing, faintly,
# Nearest to protestant: distanced, brushes, hif, brainstem, guildhall, retain, transcription, acquisitions,
# Nearest to case: subsequently, aor, caapi, ocaml, mak, magnetron, sind, tenerife,
# Nearest to return: occultists, dbv, birthday, disposal, nominations, whore, callet, alpher,
# Nearest to decades: conspirator, summarizes, organ, transporting, korn, olympia, hautes, aedile,
# Nearest to import: lefty, bwv, septuagint, misspelling, arcology, nami, parrot, saturdays,
# Nearest to day: paraffin, vulpes, wave, tristram, hogs, ltcm, mercenaries, chronic,
# Nearest to software: rustic, centrality, immanent, troy, butane, volga, sh, exogenous,
# Average loss at step 2000: 4.154114
# Average loss at step 4000: 3.577462
# Average loss at step 6000: 3.460287
# Average loss at step 8000: 3.426548
# Average loss at step 10000: 3.362874
# Nearest to office: phospholipids, defun, fontaine, valium, frobisher, kd, adequacy, dn,
# Nearest to appointed: antoninus, kathleen, screename, ding, gleichschaltung, deuteronomic, profusion, innermost,
# Nearest to changed: wronged, storehouses, mystique, charlemagne, moratorium, catalysed, pedagogic, fauna,
# Nearest to re: astrophysicists, fill, unital, metropolises, commitments, watering, plastic, ovens,
# Nearest to idea: chargers, abuses, tms, motet, missile, smallest, genocidal, explanation,
# Nearest to football: review, mujahidin, drills, mcclellan, mcleod, logged, exist, fractures,
# Nearest to continues: smoother, quintana, vought, coleco, gun, legation, dummy, gdb,
# Nearest to until: tarawa, multilinear, consider, resembled, into, julian, reluctant, un,
# Nearest to statistics: father, fugazi, quiver, realizing, nger, reveals, theodore, google,
# Nearest to protestant: distanced, hif, brushes, retain, brainstem, guildhall, transcription, acquisitions,
# Nearest to case: aor, mak, sind, caapi, hew, subsequently, personalities, cucurbitaceae,
# Nearest to return: occultists, disposal, recruiting, lithuanians, birthday, whore, martinez, natufian,
# Nearest to decades: conspirator, summarizes, transporting, organ, jocular, korn, panthera, hautes,
# Nearest to import: lefty, septuagint, arcology, nami, misspelling, bwv, trustee, saturdays,
# Nearest to day: paraffin, wave, tristram, vulpes, hogs, ltcm, mercenaries, losses,
# Nearest to software: rustic, centrality, troy, uncle, schemas, skirmishes, sh, computational,
# Average loss at step 12000: 3.314076
# Average loss at step 14000: 3.340851
# Average loss at step 16000: 3.293008
# Average loss at step 18000: 3.246277
# Average loss at step 20000: 3.213734
# Nearest to office: defun, phospholipids, fontaine, frobisher, valium, kd, adequacy, disjointed,
# Nearest to appointed: antoninus, screename, ding, gleichschaltung, kathleen, innermost, dolphin, profusion,
# Nearest to changed: storehouses, wronged, charlemagne, mystique, moratorium, catalysed, pedagogic, actual,
# Nearest to re: astrophysicists, fill, warrant, speller, metropolises, jabir, watering, plastic,
# Nearest to idea: tms, swapping, chargers, abuses, explanation, evaluation, motet, genocidal,
# Nearest to football: review, cluster, drills, exist, tokyo, fractures, mideast, crest,
# Nearest to continues: smoother, vought, coleco, quintana, legation, perverse, monroe, gun,
# Nearest to until: multilinear, tarawa, consider, into, oneself, lightsaber, during, resembled,
# Nearest to statistics: father, fugazi, realizing, quiver, wawel, theodore, nger, tangerine,
# Nearest to protestant: distanced, brushes, hif, guildhall, retain, brainstem, transcription, beast,
# Nearest to case: mak, sind, way, hew, personalities, sc, caapi, bremer,
# Nearest to return: recruiting, occultists, natufian, disposal, lithuanians, martinez, ethics, tamar,
# Nearest to decades: jocular, conspirator, years, summarizes, transporting, panthera, percent, organ,
# Nearest to import: lefty, septuagint, arcology, nami, misspelling, trustee, bwv, saturdays,
# Nearest to day: paraffin, wave, tristram, vulpes, losses, hogs, marriage, ltcm,
# Nearest to software: rustic, centrality, troy, uncle, skirmishes, painfully, computational, computer,
# Average loss at step 22000: 3.179460
# Average loss at step 24000: 3.197165
# Average loss at step 26000: 3.166954
# Average loss at step 28000: 3.133616
# Average loss at step 30000: 3.075889
# Nearest to office: defun, fontaine, phospholipids, kd, frobisher, adequacy, valium, disjointed,
# Nearest to appointed: antoninus, ding, racers, gzip, kathleen, gleichschaltung, innermost, screename,
# Nearest to changed: charlemagne, storehouses, wronged, moratorium, catalysed, actual, pedagogic, mystique,
# Nearest to re: astrophysicists, billboards, speller, jabir, fill, warrant, plastic, watering,
# Nearest to idea: tms, explanation, swapping, evaluation, abuses, smallest, chargers, genocidal,
# Nearest to football: review, drills, tokyo, mideast, cluster, arianism, micronesian, pestis,
# Nearest to continues: smoother, vought, coleco, leads, legation, led, monroe, perverse,
# Nearest to until: multilinear, during, tarawa, in, consider, into, before, lightsaber,
# Nearest to statistics: realizing, father, fugazi, jussive, theodore, wawel, tangerine, quiver,
# Nearest to protestant: distanced, hif, guildhall, brushes, brainstem, retain, transcription, beast,
# Nearest to case: way, hew, mak, sind, sc, rgb, bremer, role,
# Nearest to return: disposal, recruiting, lithuanians, natufian, martinez, tamar, whitcomb, occultists,
# Nearest to decades: years, jocular, percent, conspirator, transporting, panthera, korn, summarizes,
# Nearest to import: lefty, nami, septuagint, arcology, trustee, misspelling, bwv, saturdays,
# Nearest to day: marriage, paraffin, tristram, losses, vulpes, wave, hesitated, hogs,
# Nearest to software: rustic, centrality, computer, uncle, skirmishes, troy, painfully, computational,
# Average loss at step 32000: 3.113555
# Average loss at step 34000: 3.104679
# Average loss at step 36000: 3.015633
# Average loss at step 38000: 3.023107
# Average loss at step 40000: 3.030690
# Nearest to office: defun, fontaine, phospholipids, frobisher, kd, adequacy, valium, earthworks,
# Nearest to appointed: antoninus, founded, discovered, gzip, racers, ding, dolphin, elected,
# Nearest to changed: charlemagne, storehouses, moratorium, wronged, positrons, catalysed, done, actual,
# Nearest to re: billboards, astrophysicists, jabir, speller, fill, ldots, warrant, glamour,
# Nearest to idea: explanation, tms, swapping, evaluation, smallest, process, emergence, abuses,
# Nearest to football: arianism, review, drills, hockey, association, pestis, tokyo, bicameral,
# Nearest to continues: smoother, vought, coleco, leads, came, moved, led, legation,
# Nearest to until: during, in, since, multilinear, tarawa, consider, neck, messaging,
# Nearest to statistics: realizing, jussive, fugazi, google, tangerine, theodore, wawel, quiver,
# Nearest to protestant: distanced, guildhall, brainstem, hif, transcription, beast, retain, brushes,
# Nearest to case: way, hew, rgb, mak, sind, fact, sc, system,
# Nearest to return: natufian, disposal, tamar, martinez, refer, be, recruiting, lithuanians,
# Nearest to decades: years, percent, days, jocular, weeks, korn, panthera, transporting,
# Nearest to import: lefty, septuagint, nami, arcology, trustee, misspelling, bwv, parrot,
# Nearest to day: marriage, paraffin, losses, vulpes, year, hour, latter, decade,
# Nearest to software: rustic, centrality, uncle, computer, skirmishes, troy, elliptic, painfully,
# Average loss at step 42000: 3.003438
# Average loss at step 44000: 3.043551
# Average loss at step 46000: 2.944339
# Average loss at step 48000: 3.025479
# Average loss at step 50000: 3.062355
# Nearest to office: defun, fontaine, frobisher, adequacy, kd, detention, phospholipids, vinton,
# Nearest to appointed: elected, founded, discovered, antoninus, sent, aedile, racers, gzip,
# Nearest to changed: charlemagne, moratorium, storehouses, positrons, eastbourne, wronged, catalysed, received,
# Nearest to re: billboards, speller, ldots, astrophysicists, fill, jabir, glamour, warrant,
# Nearest to idea: explanation, tms, swapping, evaluation, possibility, process, notion, smallest,
# Nearest to football: hockey, arianism, association, drills, pestis, micronesian, review, pompey,
# Nearest to continues: smoother, vought, coleco, leads, came, moved, legation, distinguish,
# Nearest to until: during, since, multilinear, in, before, neck, messaging, throughout,
# Nearest to statistics: realizing, google, jussive, tangerine, theodore, fugazi, gallop, quiver,
# Nearest to protestant: distanced, guildhall, beast, brainstem, transcription, hif, policies, arab,
# Nearest to case: way, fact, hew, rgb, petersen, wilmot, mak, component,
# Nearest to return: refer, tamar, choose, natufian, disposal, be, keep, lithuanians,
# Nearest to decades: years, percent, days, weeks, jocular, korn, cake, panthera,
# Nearest to import: lefty, macroscopic, saturdays, bwv, septuagint, parrot, coincidental, misspelling,
# Nearest to day: marriage, paraffin, hour, decade, vulpes, year, peloponnese, losses,
# Nearest to software: rustic, computer, skirmishes, uncle, painfully, mappings, centrality, elliptic,
# Average loss at step 52000: 2.994024
# Average loss at step 54000: 2.957981
# Average loss at step 56000: 2.960693
# Average loss at step 58000: 3.003941
# Average loss at step 60000: 2.987092
# Nearest to office: defun, fontaine, kd, warmblood, frobisher, detention, adequacy, phospholipids,
# Nearest to appointed: elected, founded, discovered, sent, antoninus, built, aedile, lammas,
# Nearest to changed: charlemagne, eastbourne, moratorium, storehouses, done, actual, positrons, taken,
# Nearest to re: billboards, ldots, speller, britain, astrophysicists, glamour, fill, warrant,
# Nearest to idea: explanation, tms, possibility, smallest, notion, evaluation, swapping, process,
# Nearest to football: hockey, arianism, association, drills, review, pestis, pompey, micronesian,
# Nearest to continues: smoother, leads, came, coleco, vought, continued, began, distinguish,
# Nearest to until: since, during, in, before, neck, multilinear, messaging, throughout,
# Nearest to statistics: realizing, google, jussive, tangerine, fugazi, theodore, expert, prokofiev,
# Nearest to protestant: guildhall, beast, distanced, brainstem, arab, transcription, policies, hif,
# Nearest to case: way, rgb, fact, wilmot, hew, component, petersen, interest,
# Nearest to return: disposal, tamar, choose, keep, refer, natufian, lithuanians, be,
# Nearest to decades: years, weeks, days, percent, jocular, months, cake, tearing,
# Nearest to import: lefty, macroscopic, saturdays, bwv, septuagint, parrot, coincidental, misspelling,
# Nearest to day: marriage, paraffin, hour, decade, peloponnese, vulpes, month, losses,
# Nearest to software: rustic, computer, skirmishes, design, painfully, mappings, uncle, cad,
# Average loss at step 62000: 2.894674
# Average loss at step 64000: 2.970422
# Average loss at step 66000: 2.916595
# Average loss at step 68000: 2.901760
# Average loss at step 70000: 2.498277
# Nearest to office: detention, defun, kd, warmblood, ujjain, frobisher, fontaine, downplayed,
# Nearest to appointed: elected, founded, sent, discovered, killed, antoninus, built, lammas,
# Nearest to changed: charlemagne, come, done, taken, moratorium, contributed, conquered, eastbourne,
# Nearest to re: billboards, speller, glamour, britain, safeguards, ldots, warrant, fill,
# Nearest to idea: explanation, tms, possibility, notion, evaluation, smallest, emergence, swapping,
# Nearest to football: hockey, arianism, association, drills, championship, murad, pestis, team,
# Nearest to continues: continued, leads, smoother, came, began, coleco, vought, moved,
# Nearest to until: since, during, before, neck, in, throughout, establishes, multilinear,
# Nearest to statistics: google, realizing, tangerine, jussive, theodore, expert, fugazi, prokofiev,
# Nearest to protestant: beast, guildhall, distanced, arab, brainstem, transcription, policies, hif,
# Nearest to case: way, rgb, petersen, yields, gambeson, fact, mak, practice,
# Nearest to return: keep, disposal, choose, tamar, refer, be, oxidize, natufian,
# Nearest to decades: years, weeks, days, percent, months, jocular, cake, tearing,
# Nearest to import: lefty, macroscopic, saturdays, septuagint, teleportation, coincidental, parrot, traverses,
# Nearest to day: paraffin, marriage, hour, decade, peloponnese, maclachlan, ministerio, epr,
# Nearest to software: rustic, computer, skirmishes, painfully, mappings, design, cad, check,
# Average loss at step 72000: 2.709522
# Average loss at step 74000: 2.866544
# Average loss at step 76000: 2.862026
# Average loss at step 78000: 2.959210
# Average loss at step 80000: 2.921984
# Nearest to office: detention, officio, warmblood, defun, ujjain, thoughts, downplayed, iadb,
# Nearest to appointed: elected, sent, founded, discovered, killed, granted, antoninus, aedile,
# Nearest to changed: charlemagne, done, contributed, come, actual, came, conquered, received,
# Nearest to re: billboards, safeguards, britain, ldots, utica, glamour, speller, warrant,
# Nearest to idea: explanation, possibility, notion, tms, evaluation, smallest, piece, event,
# Nearest to football: hockey, association, basketball, team, championship, arianism, murad, drills,
# Nearest to continues: continued, began, came, smoother, leads, coleco, vought, moved,
# Nearest to until: since, during, before, in, neck, multilinear, throughout, messaging,
# Nearest to statistics: google, realizing, tangerine, jussive, expert, fugazi, theodore, prokofiev,
# Nearest to protestant: guildhall, distanced, beast, arab, brainstem, transcription, fathers, policies,
# Nearest to case: way, process, rgb, cases, wilmot, charge, yields, gambeson,
# Nearest to return: disposal, transition, choose, keep, refer, leave, oxidize, tamar,
# Nearest to decades: years, weeks, days, percent, months, jocular, cake, tearing,
# Nearest to import: lefty, macroscopic, saturdays, septuagint, parrot, teleportation, coincidental, jordi,
# Nearest to day: marriage, hour, paraffin, decade, peloponnese, month, week, vilna,
# Nearest to software: rustic, computer, skirmishes, mappings, painfully, windows, java, bentley,
# Average loss at step 82000: 2.744477
# Average loss at step 84000: 2.907591
# Average loss at step 86000: 2.928197
# Average loss at step 88000: 2.910391
# Average loss at step 90000: 2.651276
# Nearest to office: detention, officio, warmblood, ujjain, iadb, thoughts, scarp, nolan,
# Nearest to appointed: elected, sent, founded, granted, discovered, killed, ruled, former,
# Nearest to changed: done, contributed, charlemagne, come, taken, adopted, begun, conquered,
# Nearest to re: billboards, safeguards, utica, britain, ldots, glamour, revisit, wilson,
# Nearest to idea: explanation, possibility, notion, tms, smallest, event, process, evaluation,
# Nearest to football: hockey, team, basketball, championship, association, arianism, baseball, murad,
# Nearest to continues: continued, began, leads, came, smoother, coleco, decided, vought,
# Nearest to until: since, during, before, in, neck, messaging, throughout, multilinear,
# Nearest to statistics: google, realizing, expert, jussive, tangerine, mychal, prokofiev, tourist,
# Nearest to protestant: arab, religions, fathers, distanced, guildhall, beast, brainstem, transcription,
# Nearest to case: cases, process, way, charge, manner, sense, interested, wilmot,
# Nearest to return: keep, disposal, transition, deliver, leave, choose, stay, reach,
# Nearest to decades: years, weeks, days, months, percent, jocular, hours, decade,
# Nearest to import: lefty, macroscopic, saturdays, septuagint, parrot, teleportation, coincidental, jordi,
# Nearest to day: marriage, paraffin, hour, month, decade, peloponnese, epr, ministerio,
# Nearest to software: rustic, linux, windows, computer, skirmishes, design, mappings, check,
# Average loss at step 92000: 2.806771
# Average loss at step 94000: 2.751998
# Average loss at step 96000: 2.892217
# Average loss at step 98000: 2.811068
# Average loss at step 100000: 2.895387
# Nearest to office: officio, detention, iadb, nolan, thoughts, ujjain, crichton, scarp,
# Nearest to appointed: elected, sent, granted, founded, ruled, discovered, killed, former,
# Nearest to changed: done, come, contributed, taken, charlemagne, received, came, adopted,
# Nearest to re: safeguards, billboards, ldots, utica, wilson, soto, glamour, ukrainian,
# Nearest to idea: explanation, possibility, notion, tms, event, evaluation, smallest, process,
# Nearest to football: hockey, basketball, championship, team, baseball, association, arianism, champions,
# Nearest to continues: continued, began, leads, smoother, came, decided, coleco, moved,
# Nearest to until: since, during, before, neck, multilinear, establishes, messaging, throughout,
# Nearest to statistics: google, realizing, tourist, jussive, expert, tangerine, prokofiev, information,
# Nearest to protestant: fathers, arab, beast, religions, guildhall, distanced, brainstem, deluded,
# Nearest to case: cases, process, manner, assumption, way, principle, charge, wilmot,
# Nearest to return: keep, disposal, transition, deliver, leave, prepare, reach, divisive,
# Nearest to decades: years, weeks, days, months, percent, hours, jocular, decade,
# Nearest to import: lefty, macroscopic, saturdays, septuagint, teleportation, parrot, coincidental, jordi,
# Nearest to day: paraffin, marriage, month, hour, decade, ministerio, week, peloponnese,
# Nearest to software: linux, windows, skirmishes, rustic, design, programs, interface, computer,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
